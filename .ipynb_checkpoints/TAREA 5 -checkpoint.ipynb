# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Eduardo gutierrez y Juan Pablo Dominguez
#
# **Fecha:** 29 de febrero del 2024.
#
# **Expediente** :741305 y 735196.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: Link con el enlace del repositorio del creador del proyecto
#
# # Tarea 5: Clase 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

f = lambda x: 30 * (x**2 - 2*x**3 + x**4)

vector = np.linspace(0,1,1000)

a = f(optimize.fmin(lambda x: -f(x), 0, disp = False))
t = lambda x: a * np.sin(np.pi * x)

plt.figure() 
plt.plot(vector, f(vector), label = 'Función de densidad $f(x)$', color = "purple")
plt.plot(vector, t(vector), label = '$t(x)$', color = "blue")
plt.legend();
plt.show()

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2

# %% [markdown]
# Sabemos que:
#
# $$ g(x) = \frac{t(x)}{c} $$
#
# Planteamos la integral de la siguiente manera:
#
# $$ c \int_{0}^{1}t(x)dx $$
#
# Es decir:
#
# $$ a \int_{0}^{1}\sin (\pi x)dx $$
#
# El resultado es:
#
# $$ \frac{a}{\pi}[-\cos(\pi x)]_{1}^{0}$$
#
# Al evaluar los límites obtenemos:
#
# $$ \frac{2a}{\pi} $$
#
# Sustituyendo:
#
# $$ g(x) = \frac{t(x)}{c}  = \frac{a\sin(\pi x)}{\frac{2a}{\pi}} = \frac{\pi}{2}\sin(\pi x)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2

# %% [markdown]
# Para obtener $ G(x) $ es necesario integrar nuestra función encontrada en el punto anterior, es decir:
#
# $$ G(x) = \int_{0}^{x}\frac{\pi}{2}\sin(\pi x)dx $$
#
# Obteniendo:
#
# $$ \frac{1}{2}[-\cos(\pi x)]_{0}^{x} $$
#
# Al evaluar los límites tenemos como resultado:
#
# $$ -\frac{1}{2}\cos(\pi x) + \frac{1}{2} $$
#
# Simplificando e igualando a $ U $ obtenemos:
#
# $$ U = \frac{1}{2}(-\cos(\pi x) + 1) $$
#
# Despejando $ x $ llegamos al siguiente resultado:
#
# $$ 2U = -\cos(\pi x) + 1 $$
#
# $$ 2U - 1 = -\cos(\pi x) $$
#
# $$ -cos^{-1}(2U - 1) = \pi x $$
#
# $$ \frac{1}{\pi}(-cos^{-1}(2U - 1)) = x $$
#
# $$ x = \frac{1}{\pi}cos^{-1}(1 - 2U) $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2

# Graficamos g(x)

x = np.linspace(0,1,1000)
gx = (np.pi / 2) * (np.sin(np.pi * x))

plt.figure()
plt.plot(x, gx, label = '$g(x)$')
plt.title('Función de densidad $g(x)$')
plt.legend()
plt.show()

# %%
# Función: Valores aleatorios dentro de g(x) utilizando la transformada inversa

def transformada_inversa(n: 'Número de ensayos'):
    u = np.random.rand(n)
    return (1 / np.pi) * (np.arccos(1 - 2*u))
    
# Graficamos g(x) y las variables aleatorias

n = 10000
f = transformada_inversa(n)

plt.figure()
plt.plot(x, gx, label = '$g(x)$')
plt.hist(f, bins = 100, density = True, color = 'green', alpha = 0.6, label = 'Variables aleatorias')
plt.title('Función de densidad $g(x)$ y Transformada Inversa')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2
def acep_rechazo(R2: 'Variables distribuidas U~U(0,1)',
                 R1: 'Variables distribuidas como g(x)',
                 f: 'Función objetivo a generar',
                 t: 'Función que mayor a f'):

    f_x = f(R1)
    t_x = t(R1)
    condition = R2 * t_x <= f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]   
    plt.show()
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    
    return x

# %%
# Número de puntos a simular 

f = lambda x: 30 * (x**2 - 2*x**3 + x**4)
n = 500

R2 = np.random.rand(n)
R1 = transformada_inversa(n)

x = np.linspace(0, 1, 1000)

plt.figure(figsize = (8, 5))
plt.plot(x, f(x), label = '$f(x)$', lw = 3)
plt.plot(x, t(x),label='t(x)', lw = 3)
plt.title('Aceptación y Rechazo')
plt.ylabel('Probabilidad')
plt.legend()
valores_aleatorios1 = acep_rechazo(R2, R1, f, t)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.
# Out:
#   File "/var/folders/9z/nmztlly10nl2z831qbbn5hym0000gn/T/ipykernel_92229/232092477.py", line 2
#     .
#     ^
# SyntaxError: invalid syntax

# %%
# Código de solución estudiante 2
t = lambda x: a * np.ones(len(x))
x = np.arange(0, 1, 0.01)

plt.figure(figsize = (8, 5))
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.title('Aceptación y Rechazo')
plt.ylabel('Probabilidad')
plt.legend()

n = 500
R2 = np.random.rand(n)
R1 = np.random.rand(n)

valores_aleatorios2 = acep_rechazo(R2, R1, f, t)

plt.show()

# %%
senoidal = len(valores_aleatorios1) / n
constante = len(valores_aleatorios2) / n

print('Porcentaje de puntos de aceptación t(x) constante:', constante * 100, '%')
print('Porcentaje de puntos de aceptación t(x) senoidal:', senoidal * 100, '%')
# Out:
# Porcentaje de puntos de aceptación t(x) constante: 54.0 %
# Porcentaje de puntos de aceptación t(x) senoidal: 82.19999999999999 %

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2
# Graficamos función f(x)

f = lambda x: 20 * x * (1 - x)**3
x = np.linspace(0, 1, 1000)

plt.plot(x, f(x), label='$f(x)$')

# %%
max_f = f(optimize.fmin(lambda x:-f(x), 0, disp = False))
t = lambda x: max_f * np.ones(len(x))

plt.figure(figsize = (8, 5))
plt.plot(x, f(x), label='f(x)')
plt.plot(x, t(x), label='t(x)')
plt.title('Aceptación y Rechazo')
plt.ylabel('Probabilidad')
plt.legend()

n = 500
R2 = np.random.rand(n)
R1 = np.random.rand(n)

valores_aleatorios3 = acep_rechazo(R1, R2, f, t)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2
def calcular_pi(n, p):
    pi = [0] * (n + 1)  
    pi[0] = 1  

    for i in range(n):
        pi[i + 1] = ((n - i) / (i + 1)) * (p / (1 - p)) * pi[i] 
    return pi

valores_pi = calcular_pi(n_pasos, probabilidad_p)
print("Valores de pi para los primeros", n_pasos, "pasos:")
for i, valor in enumerate(valores_pi):
    print(f"p_{i}: {valor}")
# Out:
# Valores de pi para los primeros 10 pasos:
# p_0: 1
# p_1: 4.2857142857142865
# p_2: 8.265306122448981
# p_3: 9.446064139941692
# p_4: 7.084548104956269
# p_5: 3.643481882548939
# p_6: 1.3012435294817641
# p_7: 0.31867188477104424
# p_8: 0.05121512433820354
# p_9: 0.004877630889352719
# p_10: 0.0002090413238294023

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Código de solución estudiante 1
.
.
.
.

# %%
# Código de solución estudiante 2
import numpy as np
import math

def poisson(lam, size):
    # Generar variables aleatorias Poisson
    random_values = np.random.uniform(size=size)
    poisson_values = []
    for rand_val in random_values:
        k = 0
        p_accum = math.exp(-lam)
        while rand_val > p_accum:
            k += 1
            p_accum += math.exp(-lam) * (lam ** k) / math.factorial(k)
        poisson_values.append(k)
    return poisson_values

# Parámetros
lam = 3  
size = 1000 

# Generar variables aleatorias Poisson
poisson_samples = poisson(lam, size)
print("Algunos valores de la muestra Poisson:")
print(poisson_samples[:10])  # Imprimir los primeros 10 valores
# Out:
# Algunos valores de la muestra Poisson:
# [2, 2, 4, 2, 3, 3, 3, 4, 5, 7]

# %% [markdown]
# ![image.png](attachment:image.png)
